# %%
token='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6InBqY0BnYXBwLm50aHUuZWR1LnR3IiwibGV2ZWwiOiJub2F1dGgiLCJpbWFnZS11cmwiOiJodHRwczovL2xoMy5nb29nbGV1c2VyY29udGVudC5jb20vYS9BQ2c4b2NKRllDcWNxeHprN1FLMjNOcWF2M0wwTWRqWlJucURhN3B4NlEyRVlNSm45akxBQmtnPXM5Ni1jP3N6PTUwP3N6PTUwIiwiZXhwIjoxOTQ0NjM2MDkxfQ.OxTwBOTzyAetD83Rq-OUoQ-T2vudLtfBILnuLUXcuOY'

# %% [markdown]
# # EB region neuron network plot
#
# This section loads `traced-neurons.csv` and `traced-roi-connections.csv`, extracts connections that occur in the EB region, aggregates them by neuron pair, and visualizes the resulting directed network with edge widths proportional to EB synapse counts.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# Absolute data paths
DATA_DIR = Path("/home/pajucg/2D/ring_attractor_motif")
NEURONS_CSV = DATA_DIR / "traced-neurons.csv"
ROI_CONNECTIONS_CSV = DATA_DIR / "traced-roi-connections.csv"
TOTAL_CONNECTIONS_CSV = DATA_DIR / "traced-total-connections.csv"  # kept for reference

# Visualization and filtering parameters
EDGE_WEIGHT_THRESHOLD = 5      # keep EB edges with at least this many synapses
MAX_EDGES_TO_DRAW = 3000       # cap edges for plotting to avoid overplotting
RANDOM_SEED = 7                # layout reproducibility

# %%
# Load neuron metadata
neurons_df = pd.read_csv(NEURONS_CSV)
neurons_df["bodyId"] = neurons_df["bodyId"].astype(np.int64)

# Stream ROI connections and keep only EB rows; aggregate to (pre, post) counts
edge_chunks: list[pd.DataFrame] = []
chunk_iter = pd.read_csv(
    ROI_CONNECTIONS_CSV,
    usecols=["bodyId_pre", "bodyId_post", "roi", "weight"],
    dtype={
        "bodyId_pre": np.int64,
        "bodyId_post": np.int64,
        "roi": "string",
        "weight": np.int32,
    },
    chunksize=500_000,
)
for chunk in chunk_iter:
    pb_mask = chunk["roi"].str.startswith("PB", na=False)
    pb_chunk = chunk.loc[pb_mask, ["bodyId_pre", "bodyId_post", "weight"]]
    if not pb_chunk.empty:
        edge_chunks.append(pb_chunk)

if edge_chunks:
    pb_edges_raw = pd.concat(edge_chunks, ignore_index=True)
else:
    pb_edges_raw = pd.DataFrame(columns=["bodyId_pre", "bodyId_post", "weight"], dtype=np.int64)

# Aggregate EB synapses per connection pair
pb_edges_agg = (
    pb_edges_raw
    .groupby(["bodyId_pre", "bodyId_post"], as_index=False)["weight"]
    .sum()
    .rename(columns={"weight": "pb_weight"})
)

print(f"Aggregated PB connections: {len(pb_edges_agg):,}")
# Out:
# Aggregated PB connections: 21,147

# %%
# Filter edges for plotting and prepare node metadata
edges_for_plot = pb_edges_agg.copy()
if EDGE_WEIGHT_THRESHOLD and EDGE_WEIGHT_THRESHOLD > 0:
    edges_for_plot = edges_for_plot.loc[edges_for_plot["pb_weight"] >= EDGE_WEIGHT_THRESHOLD].copy()

if len(edges_for_plot) > MAX_EDGES_TO_DRAW:
    edges_for_plot = edges_for_plot.nlargest(MAX_EDGES_TO_DRAW, "pb_weight").copy()

node_ids = pd.Index(
    pd.unique(
        np.concatenate([edges_for_plot["bodyId_pre"].values, edges_for_plot["bodyId_post"].values])
    )
)

nodes_df = (
    pd.DataFrame({"bodyId_node": node_ids})
    .merge(
        neurons_df.rename(columns={"bodyId": "bodyId_node"})[["bodyId_node", "type", "instance"]],
        on="bodyId_node",
        how="left",
    )
)

print(f"Nodes to draw: {len(nodes_df):,}; Edges to draw: {len(edges_for_plot):,}")
# Out:
# Nodes to draw: 473; Edges to draw: 3,000

# %%
# Build a directed graph from EB connections
G = nx.DiGraph()

# Add nodes with attributes
for _, r in nodes_df.iterrows():
    G.add_node(
        int(r["bodyId_node"]),
        type=None if pd.isna(r["type"]) else str(r["type"]),
        instance=None if pd.isna(r["instance"]) else str(r["instance"]),
    )

# Add weighted directed edges
for _, r in edges_for_plot.iterrows():
    G.add_edge(int(r["bodyId_pre"]), int(r["bodyId_post"]), weight=int(r["pb_weight"]))

print(f"Graph info: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
# Out:
# Graph info: 473 nodes, 3000 edges

# %%
# Visualize and save the EB network graph
plt.figure(figsize=(12, 10))

if G.number_of_nodes() == 0:
    print("No EB edges to plot with the current threshold.")
else:
    # Choose layout based on graph size
    if G.number_of_nodes() <= 200:
        pos = nx.kamada_kawai_layout(G, weight="weight")
    else:
        pos = nx.spring_layout(G, weight="weight", seed=RANDOM_SEED)

    # Node sizes scaled by (undirected) degree
    deg_map = dict(G.degree())
    node_sizes = np.array([deg_map[n] for n in G.nodes()], dtype=float)
    if node_sizes.size and node_sizes.max() > 0:
        node_sizes = 50 + 150 * (node_sizes / node_sizes.max())
    else:
        node_sizes = np.full(G.number_of_nodes(), 50.0)

    # Edge widths scaled by EB weight
    edge_weights = np.array([d["weight"] for _, _, d in G.edges(data=True)], dtype=float)
    if edge_weights.size:
        if edge_weights.max() > edge_weights.min():
            widths = 1.0 + 2.0 * (edge_weights - edge_weights.min()) / (edge_weights.max() - edge_weights.min())
        else:
            widths = np.full(edge_weights.shape[0], 1.0)
    else:
        widths = 1.0

    nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color="#4472c4", alpha=0.85)
    nx.draw_networkx_edges(G, pos, width=widths, edge_color="#999999", arrowsize=10, alpha=0.5)

    # Label only small graphs for readability
    if G.number_of_nodes() <= 60:
        labels = {n: str(n) for n in G.nodes()}
        nx.draw_networkx_labels(G, pos, labels=labels, font_size=8)

    plt.title(f"EB region neuron network (threshold >= {EDGE_WEIGHT_THRESHOLD}, edges: {G.number_of_edges():,})")
    plt.axis("off")
    out_path = DATA_DIR / "pb_network.png"
    plt.tight_layout()
    plt.savefig(out_path, dpi=200)
    plt.show()
    print(f"Saved figure to: {out_path}")
# Out:
# Saved figure to: /home/pajucg/2D/ring_attractor_motif/eb_network.png

# %% [markdown]
# ## EB adjacency matrix
#
# Builds a directed EB-only adjacency matrix from `pb_edges_agg`, shows a 20x20 preview, and saves full matrices to CSV (bodyId-indexed and human-readable named).

# %%
# Build EB adjacency matrices (bodyId-indexed and named) and save to CSV
from IPython.display import display

# All node ids participating in EB edges (no thresholding)
node_ids_all = pd.Index(
    pd.unique(
        np.concatenate([pb_edges_agg["bodyId_pre"].values, pb_edges_agg["bodyId_post"].values])
    )
)

# Directed adjacency (rows: pre, cols: post), fill missing with 0
pb_matrix_bodyId = (
    pb_edges_agg
    .pivot_table(index="bodyId_pre", columns="bodyId_post", values="pb_weight", fill_value=0, aggfunc="sum")
    .reindex(index=node_ids_all, columns=node_ids_all, fill_value=0)
)
# Ensure integer dtype
pb_matrix_bodyId = pb_matrix_bodyId.astype(np.int64)

# Create readable labels: instance (bodyId) or type/bodyId fallback
all_nodes_df = (
    pd.DataFrame({"bodyId": node_ids_all})
    .merge(neurons_df[["bodyId", "type", "instance"]], on="bodyId", how="left")
)

def _label_for_row(row: pd.Series) -> str:
    instance_str = str(row["instance"]) if pd.notna(row["instance"]) and str(row["instance"]).strip() else ""
    type_str = str(row["type"]) if pd.notna(row["type"]) and str(row["type"]).strip() else ""
    base = instance_str or type_str or str(int(row["bodyId"]))
    return f"{base} ({int(row['bodyId'])})"

bodyId_to_label = {int(r["bodyId"]): _label_for_row(r) for _, r in all_nodes_df.iterrows()}

# Named matrix with readable labels (values identical to bodyId matrix)
pb_matrix_named = pb_matrix_bodyId.copy()
pb_matrix_named.index = [bodyId_to_label[int(i)] for i in pb_matrix_named.index]
pb_matrix_named.columns = [bodyId_to_label[int(i)] for i in pb_matrix_named.columns]

# Save CSVs
bid_path = DATA_DIR / "pb_adjacency_matrix.csv"
named_path = DATA_DIR / "pb_adjacency_matrix_named.csv"
pb_matrix_bodyId.to_csv(bid_path)
pb_matrix_named.to_csv(named_path)
print(f"Saved bodyId matrix to: {bid_path}  | shape: {pb_matrix_bodyId.shape}")
print(f"Saved named matrix  to: {named_path} | shape: {pb_matrix_named.shape}")

# Show a small preview to avoid overwhelming the notebook
display(pb_matrix_named.iloc[:20, :20])
# Out:
# Saved bodyId matrix to: /home/pajucg/2D/ring_attractor_motif/pb_adjacency_matrix.csv  | shape: (796, 796)
# Saved named matrix  to: /home/pajucg/2D/ring_attractor_motif/pb_adjacency_matrix_named.csv | shape: (796, 796)
#                                 OA-VPM3(NO2/NO3)_R (329566174)  \
# OA-VPM3(NO2/NO3)_R (329566174)                               0
# PEN_b(PB06b)_L4 (387023620)                                  0
# EPG(PB08)_L3 (387364605)                                     0
# EPG(PB08)_R4 (416642425)                                     0
# PFNv(PB05)_R4_C7 (417998204)                                 0
# PFGs(PB10)_L2_C2 (419060083)                                 0
# PFNd(PB04)_L5_C4 (446714544)                                 0
# EPG(PB08)_L3 (449438847)                                     0
# PFNa(PB03)_L4_C3 (478077561)                                 0
# EPG(PB08)_R3 (478375456)                                     0
# PFNv(PB05)_L5_C4 (478427368)                                 0
# PFL2(PB12b)_R1_C4 (481112669)                                0
# PFL1(PB12a)_L2_C3 (481121605)                                0
# PEN_a(PB06a)_L7 (508793049)                                  0
# PEN_b(PB06b)_L4 (539462336)                                  0
# EPG(PB08)_R3 (541118908)                                     0
# PEN_b(PB06b)_L4 (539462336)                        0                    0
# EPG(PB08)_R3 (541118908)                           0                    0
# PFNa(PB03)_R4_C7 (541119189)                       0                    0
# EPG(PB08)_L6 (541870397)                           0                    0
# PPL204_R (542039038)                               0                    0
# DNp44_R (542751938)                                0                    0

# %% [markdown]
# # EB matrix

# %%
import matplotlib.pyplot as plt
W = pb_matrix_bodyId.values  # Convert DataFrame to numpy array
# Plot the weight matrix W
plt.figure(figsize=(10, 8))
plt.imshow(W, cmap='Reds', aspect='auto', vmax=100)
plt.colorbar(label='Weight')
plt.title('Weight Matrix W')
plt.xlabel('Target Neuron')
plt.ylabel('Source Neuron')
plt.show()

# %% [markdown]
# # blind sort

# %%
from Sorter import MatrixSorter

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

# -----------------------------
# Parameters
# -----------------------------
N_pattern = 16          # First 16 neurons have special pattern
N_total   = 40          # Total number of neurons

# Initialize matrix with small background noise
W = np.random.randint(0, 15, size=(N_total, N_total))

# -----------------------------
# Pattern structure for first 16 neurons:
# Indices 0-7:  L8, L7, L6, L5, L4, L3, L2, L1
# Indices 8-15: R1, R2, R3, R4, R5, R6, R7, R8
#
# Connection pattern:
#  - Strong self-connections (main diagonal)
#  - L_k -> R_k connections (upper off-diagonal band)
#  - R_k -> L_k connections (lower off-diagonal band)
# -----------------------------

for i in range(8):
    idx_L = i          # L neurons: indices 0-7
    idx_R = 8 + i      # R neurons: indices 8-15

    # Self-connections (main diagonal)
    W[idx_L, idx_L] = np.random.randint(250, 340)   # L self-connection
    W[idx_R, idx_R] = np.random.randint(250, 340)   # R self-connection

    # Cross-connections between L and R (off-diagonal bands)
    w_L_to_R = np.random.randint(140, 230)
    w_R_to_L = np.random.randint(140, 230)

    W[idx_L, idx_R] = w_L_to_R   # L -> R connection
    W[idx_R, idx_L] = w_R_to_L   # R -> L connection

# Reduce background values outside the pattern region to make bands more visible
background_mask = np.ones_like(W, dtype=bool)
background_mask[:N_pattern, :N_pattern] = False
W[background_mask] = np.random.randint(0, 250, size=W[background_mask].shape)

# Extract the pattern submatrix
W_pattern = W[:N_pattern, :N_pattern]

# Visualize the pattern matrix
plt.figure(figsize=(8, 6))
plt.imshow(W_pattern, cmap='Reds', aspect='equal')
plt.colorbar(label='Connection Strength')
plt.title('Pattern Matrix (16x16 subset)')
plt.xlabel('Target Neuron')
plt.ylabel('Source Neuron')

# Add tick labels to show L/R structure
tick_labels = ['L8', 'L7', 'L6', 'L5', 'L4', 'L3', 'L2', 'L1', 
               'R1', 'R2', 'R3', 'R4', 'R5', 'R6', 'R7', 'R8']
plt.xticks(range(16), tick_labels, rotation=45)
plt.yticks(range(16), tick_labels)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from Sorter import MatrixSorter

# Get the sorted order from blind_sort function
W = pb_matrix_bodyId.values  # Convert DataFrame to numpy array
N = W.shape[0]

# Use robust spectral-core sorting algorithm
method = 'blind_improved'
W_sorted, perm = MatrixSorter(method=method).sort(W)

# Build readable labels from neuron metadata (prefer instance, then type, else bodyId)
label_map_df = neurons_df[["bodyId", "instance", "type"]].copy()

def _to_label(row):
    inst = str(row["instance"]).strip() if pd.notna(row["instance"]) else ""
    if inst:
        return inst
    typ = str(row["type"]).strip() if pd.notna(row["type"]) else ""
    return typ if typ else str(int(row["bodyId"]))

id_to_label = {int(row["bodyId"]): _to_label(row) for _, row in label_map_df.iterrows()}

# Names in original and sorted order
original_ids = pb_matrix_bodyId.index.tolist()
original_neuron_names = [id_to_label.get(int(b), str(int(b))) for b in original_ids]
sorted_neuron_names = [original_neuron_names[i] for i in perm]

# Apply sorting to matrix
W_sorted = W[perm][:, perm]

# Print sorted neuron names
print("Sorted neuron names:")
for i, name in enumerate(sorted_neuron_names):
    print(f"{i}: {name}")
# Out:
# Sorted neuron names:
# 0: Delta7(PB15)_L7R2_L
# 1: Delta7(PB15)_L7R2_L
# 2: Delta7(PB15)_L7R2_L
# 3: EPG(PB08)_R3
# 4: EPG(PB08)_R3
# 5: EPG(PB08)_R3
# 6: Delta7(PB15)_L6R3_L
# 7: Delta7(PB15)_L6R3_L
# 8: Delta7(PB15)_L6R3_L
# 9: Delta7(PB15)_L6R3_L
# 10: Delta7(PB15)_L7R3_L
# 11: Delta7(PB15)_L6R3_L
# 12: IbSpsP(PB17)_R2
# 13: IbSpsP(PB17)_R2/3
# 14: IbSpsP(PB17)_R3
# 15: IbSpsP(PB17)_L6/7
# 16: IbSpsP(PB17)_L6/7
# 17: IbSpsP(PB17)_R9
# 18: IbSpsP(PB17)_R9
# 19: IbSpsP(PB17)_L8
# 20: EPGt(PB09)_R9
# 21: EPGt(PB09)_R9
# 22: EPG(PB08)_L1
# 23: EPG(PB08)_L1
# 24: EPG(PB08)_R8
# 25: EPG(PB08)_R8
# 26: EPG(PB08)_R8
# 27: EPG(PB08)_R8
# 28: EPGt(PB09)_L9
# 29: EPGt(PB09)_L9
# 30: IbSpsP(PB17)_R7/8
# 31: IbSpsP(PB17)_R8
# 32: IbSpsP(PB17)_L9
# 33: EPG(PB08)_R2
# 34: EPG(PB08)_R2
# 35: EPG(PB08)_L7
# 36: EPG(PB08)_L7
# 37: EPG(PB08)_L7
# 38: P1-9(PB19)_L
# 39: P1-9(PB19)_R
# 40: EPG(PB08)_R1
# 41: EPG(PB08)_R1
# 42: EPG(PB08)_L8
# 43: EPG(PB08)_L8
# 44: EPG(PB08)_L8
# 45: EPG(PB08)_L8
# 46: P6-8P9(PB14)_L
# 47: SIFa(PDM34)
# 48: LPsP(PB13)_R
# 49: LPsP(PB13)_L
# 50: Delta7(PB15)_L8R1R9_L
# 51: Delta7(PB15)_L8R1R9_L
# 52: Delta7(PB15)_L8R1R9_L
# 53: Delta7(PB15)_L8R1R9_L
# 54: Delta7(PB15)_L8R1R9_L
# 55: Delta7(PB15)_L1L9R8_R
# 56: Delta7(PB15)_L1L9R8_R
# 57: Delta7(PB15)_L1L9R8_R
# 58: Delta7(PB15)_L1L9R8_R
# 59: Delta7(PB15)_L1L9R8_R
# 60: SIFa(PDM34)
# 61: SIFa(PDM34)
# 62: Delta7(PB15)_L4R5_R
# 63: Delta7(PB15)_L4R5_R
# 64: Delta7(PB15)_L4R5_R
# 65: Delta7(PB15)_L4R5_R
# 66: Delta7(PB15)_L4R5_R
# 67: EPG(PB08)_R5
# 68: EPG(PB08)_R5
# 69: EPG(PB08)_R5
# 70: EPG(PB08)_L4
# 71: EPG(PB08)_L4
# 72: EPG(PB08)_L4
# 73: Delta7(PB15)_L5R4_L
# 74: Delta7(PB15)_L5R4_L
# 75: Delta7(PB15)_L5R4_L
# 76: Delta7(PB15)_L5R4_L
# 77: Delta7(PB15)_L5R4_L
# 78: Delta7(PB15)_L6R4_L
# 79: Delta7(PB15)_L6R4_L
# 80: EPG(PB08)_L5
# 81: EPG(PB08)_L5
# 82: EPG(PB08)_L5
# 83: EPG(PB08)_L6
# 84: EPG(PB08)_L6
# 85: EPG(PB08)_L6
# 86: EPG(PB08)_R4
# 87: EPG(PB08)_R4
# 88: EPG(PB08)_R4
# 89: IbSpsP(PB17)_R3/4/5
# 90: IbSpsP(PB17)_R4
# 91: IbSpsP(PB17)_L5/6
# 92: IbSpsP(PB17)_R3/4/5
# 93: DNp44_R
# 94: IB048(PDM33)_L
# 95: SpsP(PB16)_L
# 96: SpsP(PB16)_L
# 97: hDeltaB_04_C4
# 98: EL(EQ5)_R
# 99: SIP081(PDM13)_L
# 100: SpsP(PB16)_R
# 101: ATL018(PDL20)_L
# 102: (PDL14)_L
# 103: SpsP(PB16)_R
# 104: FC1D(FQ6)_C3_R
# 105: ATL018(PDL20)_L
# 106: (PDL14)_L
# 107: ATL038(PDM33)_L
# 108: ATL032(PDM28)_L
# 109: ATL043_R
# 110: vDeltaK_C7
# 111: SLP325_R
# 112: ATL021_R
# 113: OA-VPM3(NO2/NO3)_R
# 114: LHPV6f1_R
# 115: PPL204(PVL17)_L
# 116: IbSpsP(PB17)_L2/R2/4
# 117: IbSpsP(PB17)_R7/9
# 118: IbSpsP(PB17)_L2
# 119: EPG(PB08)_L2
# 120: EPG(PB08)_L2
# 121: EPG(PB08)_R7
# 122: EPG(PB08)_R7
# 123: EPG(PB08)_R7
# 124: Delta7(PB15)_L2R7_R
# 125: Delta7(PB15)_L2R7_R
# 126: Delta7(PB15)_L2R7_R
# 127: Delta7(PB15)_L3R6_R
# 128: Delta7(PB15)_L2R7_R
# 129: Delta7(PB15)_L2R7_R
# 130: EPG(PB08)_R6
# 131: EPG(PB08)_R6
# 132: EPG(PB08)_R6
# 133: EPG(PB08)_L3
# 134: EPG(PB08)_L3
# 135: EPG(PB08)_L3
# 136: Delta7(PB15)_L4R6_R
# 137: Delta7(PB15)_L4R6_R
# 138: Delta7(PB15)_L3R6_R
# 139: Delta7(PB15)_L3R6_R
# 140: Delta7(PB15)_L3R6_R
# 141: IbSpsP(PB17)_R5/6
# 142: IbSpsP(PB17)_L4
# 143: IbSpsP(PB17)_R6
# 144: IbSpsP(PB17)_R6
# 145: IbSpsP(PB17)_L2/4
# 146: IbSpsP(PB17)_L3/4
# 147: PFR_b(PB11b)_L3_C3
# 148: SIFa(PDM34)
# 149: P6-8P9(PB14)_R
# 150: P6-8P9(PB14)_R
# 151: PPL204_R
# 152: ATL032_R
# 153: (PDL14)_L
# 154: PFR_a(PB11a)_L4_C4
# 155: PFL1(PB12a)_R5_C4
# 156: PFL3(PB12c)_R5_C3
# 157: PFGs(PB10)_R5_C5
# 158: PFR_a(PB11a)_R5_C5
# 159: PFL3(PB12c)_R5_C3
# 160: PFR_a(PB11a)_R5_C5
# 161: PEG(PB07)_R5
# 162: PFL2(PB12b)_L5_C9
# 163: PFR_b(PB11b)_L4_C5
# 164: PFR_b(PB11b)_R5_C4
# 165: PEN_a(PB06a)_R5
# 166: PFNp_b(PB01b)_R5_C6
# 167: PFNm_b(PB02b)_R5_C6
# 168: PFNp_d(PB01a)_R5_C6
# 169: PFNp_d(PB01a)_R5_C6
# 170: PFNv(PB05)_R5_C6
# 171: PFNd(PB04)_R5_C5
# 172: PEN_b(PB06b)_R5
# 173: PFNa(PB03)_R5_C6
# 174: PFNp_b(PB01b)_R5_C6
# 175: PFNp_c(PB01c)_R5_C6
# 176: PFNa(PB03)_R5_C6
# 177: PFNd(PB04)_R5_C5
# 178: PFNp_a(PB01a)_R5_C6
# 179: PFNp_a(PB01a)_R5_C6
# 180: PFNp_e(PB01a)_R5_C6
# 181: PFNp_c(PB01c)_R5_C6
# 182: PFNp_b(PB01b)_R5_C6
# 183: PFNp_b(PB01b)_R5_C6
# 184: PFNm_a(PB02a)_R5_C6
# 185: PFNp_b(PB01b)_R5_C6
# 186: PFNp_d(PB01a)_L_C3_irreg
# 187: PFNm_b(PB02b)_L5_C4
# 188: PFNp_d(PB01a)_L4_C3
# 189: PFNp_d(PB01a)_L4_C3
# 190: PEN_a(PB06a)_L4
# 191: PEN_a(PB06a)_L4
# 192: PFL2(PB12b)_L4_C8
# 193: PEG(PB07)_L4
# 194: PFR_a(PB11a)_L4_C4
# 195: PFL3(PB12c)_L4_C6
# 196: PFGs(PB10)_L4_C4
# 197: PFL1(PB12a)_L4_C5
# 198: PFNa(PB03)_L4_C3
# 199: PFNp_b(PB01b)_L4_C3
# 200: PFNp_b(PB01b)_L4_C3
# 201: PFNd(PB04)_L4_C3
# 202: PFNp_c(PB01c)_L4_C3
# 203: PFNa(PB03)_L4_C3
# 204: PEN_b(PB06b)_L4
# 205: PFNa(PB03)_L4_C3
# 206: PFNa(PB03)_L4_C3
# 207: PFNd(PB04)_L4_C3
# 208: PFNp_c(PB01c)_L4_C3
# 209: PFNd(PB04)_L4_C3
# 210: PFNp_c(PB01c)_L4_C3
# 211: PEN_b(PB06b)_L4
# 212: PFNa(PB03)_L4_C3
# 213: PFNp_e(PB01a)_L4_C3
# 214: PFNp_a(PB01a)_L4_C3
# 215: PFNp_e(PB01a)_L4_C3
# 216: PFNp_a(PB01a)_L4_C3
# 217: PFNv(PB05)_L4_C3
# 218: PFNp_b(PB01b)_L4_C3
# 219: PFNm_a(PB02a)_L4_C3
# 220: PFNp_b(PB01b)_L4_C3
# 221: PFNp_b(PB01b)_L4_C3
# 222: PFNm_b(PB02b)_L4_C3
# 223: PFNm_a(PB02a)_L4_C3
# 224: PFNm_b(PB02b)_L4_C3
# 225: PFNp_a(PB01a)_L4_C3
# 226: PFNv(PB05)_L4_C3
# 227: PFNp_b(PB01b)_L6_C5_irreg
# 228: PFNp_a(PB01a)_L4_C3
# 229: PFNp_b(PB01b)_L4_C3
# 230: PFNd(PB04)_L4_C3
# 231: PFNa(PB03)_L4_C3
# 232: PFNp_b(PB01b)_L4_C3
# 233: PFNp_b(PB01b)_L4_C3
# 234: PFNp_c(PB01c)_L4_C3
# 235: PFNp_b(PB01b)_L4_C3
# 236: PFL2(PB12b)_L3_C7
# 237: PFL2(PB12b)_L3_C7
# 238: PFR_a(PB11a)_L3_C3
# 239: PFL3(PB12c)_L3_C5
# 240: PFL1(PB12a)_L3_C4
# 241: PFR_a(PB11a)_L3_C3
# 242: PFGs(PB10)_L3_C3
# 243: PEG(PB07)_L3
# 244: PFR_b(PB11b)_L3_C4
# 245: PFNv(PB05)_L3_C2
# 246: PFNp_a(PB01a)_L3_C2
# 247: PFNp_e(PB01a)_L3_C2
# 248: PFNp_b(PB01b)_L3_C2
# 249: PFNd(PB04)_L3_C2
# 250: PFNd(PB04)_L3_C2
# 251: PFNa(PB03)_L3_C2
# 252: PEN_b(PB06b)_L3
# 253: PFNa(PB03)_L3_C2
# 254: PFNm_a(PB02a)_L3_C2
# 255: PFNp_b(PB01b)_L3_C2
# 256: PFNp_c(PB01c)_L3_C2
# 257: PFNp_c(PB01c)_L3_C2
# 258: PFNm_b(PB02b)_L3_C2
# 259: PFNp_b(PB01b)_L3_C2
# 260: PFNp_a(PB01a)_L3_C2
# 261: PFNp_b(PB01b)_L3_C2
# 262: PFNp_d(PB01a)_L3_C2
# 263: PFNp_a(PB01a)_L3_C2
# 264: PFNp_b(PB01b)_L3_C2
# 265: PFNp_d(PB01a)_L3_C2
# 266: PFL3(PB12c)_L3_C5
# 267: PFR_a(PB11a)_R6_C4
# 268: PFL1(PB12a)_R6_C3
# 269: PFL3(PB12c)_R6_C2
# 270: PFGs(PB10)_R6_C4
# 271: PFR_a(PB11a)_R6_C3
# 272: PFNp_d(PB01a)_R7_C4
# 273: PFNp_d(PB01a)_R6_C5
# 274: PFNp_d(PB01a)_R6_C5
# 275: PFNp_c(PB01c)_R6_C5
# 276: PFNp_a(PB01a)_R6_C5
# 277: PFNp_b(PB01b)_R6_C5
# 278: PFNp_a(PB01a)_R6_C5
# 279: PFNp_b(PB01b)_R6_C5
# 280: PFNp_a(PB01a)_R6_C5
# 281: PFNp_b(PB01b)_R6_C5
# 282: PFNp_b(PB01b)_R6_C5
# 283: PFNp_b(PB01b)_R6_C5
# 284: PFNm_b(PB02b)_R6_C5
# 285: PFNm_b(PB02b)_R6_C5
# 286: PFNp_b(PB01b)_R6_C5
# 287: PFNp_b(PB01b)_R6_C5
# 288: PFNp_b(PB01b)_R6_C5
# 289: PFNp_b(PB01b)_R6_C5
# 290: PFNp_b(PB01b)_R6_C5
# 291: PFNp_c(PB01c)_R6_C5
# 292: PFNp_e(PB01a)_R6_C5
# 293: PFNm_a(PB02a)_R6_C5
# 294: PFNd(PB04)_R6_C4
# 295: PFNp_a(PB01a)_R6_C5
# 296: PFNp_a(PB01a)_R6_C5
# 297: PFNv(PB05)_R6_C5
# 298: PFNa(PB03)_R6_C5
# 299: PFNa(PB03)_R6_C5
# 300: PEN_b(PB06b)_R6
# 301: PFNd(PB04)_R6_C4
# 302: PFNa(PB03)_R6_C5
# 303: PFNp_a(PB01a)_R6_C5
# 304: PFNp_c(PB01c)_R6_C5
# 305: PFNd(PB04)_R6_C4
# 306: PFNa(PB03)_R6_C5
# 307: PEN_b(PB06b)_R6
# 308: PFNa(PB03)_R6_C5
# 309: PFNa(PB03)_R6_C5
# 310: PFNp_b(PB01b)_R6_C5
# 311: PFNm_a(PB02a)_R6_C5
# 312: PFNd(PB04)_R6_C4
# 313: PFNp_b(PB01b)_R6_C5
# 314: PFNp_c(PB01c)_R6_C5
# 315: PFNv(PB05)_R6_C5
# 316: PFNp_e(PB01a)_R6_C5
# 317: PFNp_a(PB01a)_R6_C5
# 318: PFR_b(PB11b)_R6_C3
# 319: PEN_a(PB06a)_L3
# 320: PEG(PB07)_R6
# 321: PEN_a(PB06a)_R6
# 322: PEN_a(PB06a)_R6
# 323: PEN_a(PB06a)_R3
# 324: PEN_a(PB06a)_L8
# 325: PEG(PB07)_L2
# 326: PEN_a(PB06a)_L2
# 327: PFNp_b(PB01b)_L2_C1
# 328: PFNp_a(PB01a)_L2_C1
# 329: PFNp_b(PB01b)_L2_C1
# 330: PFNp_c(PB01c)_L2_C1
# 331: PFNm_a(PB02a)_L2_C1
# 332: PFNa(PB03)_L2_C1
# 333: PFNd(PB04)_L2_C1
# 334: PFNd(PB04)_L2_C1
# 335: PFNa(PB03)_L2_C1
# 336: PFNa(PB03)_L2_C1
# 337: PFNp_a(PB01a)_L2_C1
# 338: PFNp_b(PB01b)_L2_C1
# 339: PFNp_e(PB01a)_L2_C1
# 340: PFNp_c(PB01c)_L2_C1
# 341: PFNm_b(PB02b)_L2_C1
# 342: PFNp_d(PB01a)_L2_C1
# 343: PFNp_b(PB01b)_L2_C1
# 344: PFNp_a(PB01a)_L2_C1
# 345: PFNp_b(PB01b)_L2_C1
# 346: PFGs(PB10)_L2_C2
# 347: PFNv(PB05)_L2_C1
# 348: PFL2(PB12b)_L2_C6
# 349: PFR_a(PB11a)_L2_C2
# 350: PEN_b(PB06b)_L2
# 351: PFR_a(PB11a)_L2_C2
# 352: PFL1(PB12a)_L2_C3
# 353: PFL3(PB12c)_L2_C4
# 354: PFL3(PB12c)_L2_C9_irreg
# 355: PEN_a(PB06a)_R7
# 356: PFNp_a(PB01a)_R7_C4
# 357: PFNp_b(PB01b)_R7_C4
# 358: PFNd(PB04)_R7_C3
# 359: PFNp_c(PB01c)_R7_C4
# 360: PFNp_b(PB01b)_R7_C4
# 361: PFNm_a(PB02a)_R7_C4
# 362: PFNp_b(PB01b)_R7_C4
# 363: PFNp_e(PB01a)_R7_C4
# 364: PFNp_a(PB01a)_R7_C4
# 365: PFNp_b(PB01b)_R7_C4
# 366: PFNv(PB05)_R7_C3
# 367: PFNm_a(PB02a)_R7_C4
# 368: PFNp_b(PB01b)_R7_C4
# 369: PFNa(PB03)_R7_C4
# 370: PFNd(PB04)_R7_C3
# 371: PFNa(PB03)_R7_C4
# 372: PEN_b(PB06b)_R7
# 373: PFNa(PB03)_R7_C4
# 374: PFNp_a(PB01a)_R7_C4
# 375: PFNp_c(PB01c)_R7_C4
# 376: PFNp_b(PB01b)_R7_C4
# 377: EL(EQ5)_R
# 378: FS1A(FQ9)_C3_R
# 379: PEG(PB07)_R7
# 380: PFR_b(PB11b)_R7_C2
# 381: PFR_a(PB11a)_R7_C3
# 382: PFGs(PB10)_R7_C3
# 383: PFL1(PB12a)_R7_C1
# 384: PFL3(PB12c)_R7_C1
# 385: PEN_a(PB06a)_L9
# 386: PFNp_b(PB01b)_L9_C9
# 387: PFNm_b(PB02b)_L9_C9
# 388: PFNp_b(PB01b)_L9_C9
# 389: PFNp_b(PB01b)_L9_C8
# 390: PFNp_d(PB01a)_L9_C8
# 391: PFNp_a(PB01a)_L9_C8
# 392: PFNp_b(PB01b)_L9_C9
# 393: PFNp_b(PB01b)_L9_C8
# 394: PFNp_c(PB01c)_L9_C9
# 395: PFNp_c(PB01c)_L9_C9
# 396: PFNm_a(PB02a)_L9_C9
# 397: PFNm_a(PB02a)_L9_C9
# 398: PFNp_e(PB01a)_L9_C8
# 399: PFNp_c(PB01c)_L9_C9
# 400: PFNd(PB04)_L9_C8
# 401: PFNa(PB03)_L9_C9
# 402: PFNp_b(PB01b)_L9_C8
# 403: PFNp_b(PB01b)_L9_C9
# 404: PFNp_c(PB01c)_L9_C9
# 405: PFNp_b(PB01b)_L9_C9
# 406: PFNp_a(PB01a)_L9_C8
# 407: PFNv(PB05)_L9_C9
# 408: PFNa(PB03)_L9_C9
# 409: PFNd(PB04)_L9_C8
# 410: PFNa(PB03)_L9_C9
# 411: PEN_b(PB06b)_L9
# 412: PEN_b(PB06b)_L9
# 413: PFR_a(PB11a)_L1_C9_irreg
# 414: PFNp_a(PB01a)_L9_C8
# 415: PEG(PB07)_L1
# 416: PEG(PB07)_L9
# 417: PFGs(PB10)_L1_C9_irreg
# 418: PFGs(PB10)_R8_C2
# 419: PFR_b(PB11b)_L1_C2
# 420: PFR_b(PB11b)_L1_C9_irreg
# 421: PFL1(PB12a)_L1_C8_irreg
# 422: PFL2(PB12b)_L1_C5
# 423: PFL3(PB12c)_L1_C3
# 424: PFR_a(PB11a)_L1_C9_irreg
# 425: PFL3(PB12c)_L1_C3
# 426: PFL3(PB12c)_L1_C8_irreg
# 427: PFNp_b(PB01b)_R8_C3
# 428: PEN_a(PB06a)_R8
# 429: PFNp_a(PB01a)_R8_C3
# 430: PEG(PB07)_R8
# 431: PFNv(PB05)_R8_C3
# 432: PFNp_d(PB01a)_R8_C3
# 433: PFNp_b(PB01b)_R8_C3
# 434: PFNp_d(PB01a)_R8_C3
# 435: PFNa(PB03)_R8_C3
# 436: PEN_b(PB06b)_R8
# 507: PFNp_c(PB01c)_L8_C7
# 508: PFNa(PB03)_L8_C7
# 509: PEN_b(PB06b)_L8
# 510: PFNa(PB03)_L8_C7
# 511: PFNp_b(PB01b)_L8_C7
# 512: PFNp_c(PB01c)_L8_C7
# 513: PFNd(PB04)_L8_C7
# 514: PFNp_c(PB01c)_L8_C7
# 515: PFNp_a(PB01a)_L8_C7
# 516: PFGs(PB10)_L9_C9
# 517: PFNd(PB04)_L8_C7
# 518: PFNm_a(PB02a)_L8_C7
# 519: PFNp_b(PB01b)_L8_C7
# 520: PFNp_d(PB01a)_L8_C7
# 521: PFGs(PB10)_R9_C1
# 522: PEG(PB07)_L8
# 523: PEG(PB07)_R1
# 524: PFR_a(PB11a)_R1_C1_irreg
# 525: PFGs(PB10)_L8_C8
# 526: PFNa(PB03)_L8_C8
# 527: PFR_b(PB11b)_R1_C1_irreg
# 528: PFGs(PB10)_R1_C1_irreg
# 529: PFR_b(PB11b)_R1_C8
# 530: PFR_a(PB11a)_R1_C1_irreg
# 531: PFL1(PB12a)_R1_C2_irreg
# 532: PFR_a(PB11a)_L8_C8
# 533: PFL2(PB12b)_R1_C4
# 534: PFL3(PB12c)_R1_C7
# 535: PFL3(PB12c)_R1_C2_irreg
# 536: PFL3(PB12c)_R1_C7
# 537: PFNp_b(PB01b)_L6_C5
# 538: PFNp_b(PB01b)_L6_C5
# 539: PFNp_a(PB01a)_L6_C5
# 540: PFNp_b(PB01b)_L6_C5
# 541: PFNp_e(PB01a)_L6_C5
# 542: PFNp_b(PB01b)_L6_C5
# 543: PFNp_b(PB01b)_L6_C5
# 544: PFNp_d(PB01a)_L5_C4
# 545: PFNp_d(PB01a)_L5_C4
# 546: PFNp_d(PB01a)_L6_C5
# 547: PFNp_b(PB01b)_L6_C5
# 548: PEN_a(PB06a)_L6
# 549: PEN_a(PB06a)_L6
# 550: PEG(PB07)_L6
# 551: PFNp_a(PB01a)_L6_C5
# 552: PFNp_c(PB01c)_L6_C5
# 553: PEN_a(PB06a)_R4
# 554: PEN_a(PB06a)_R4
# 555: PEG(PB07)_R4
# 556: PFL2(PB12b)_R4_C2
# 557: PFL2(PB12b)_R5_C1
# 558: PFNv(PB05)_L6_C5
# 559: PFNv(PB05)_L6_C5
# 560: PFNd(PB04)_L6_C5
# 561: PFNm_a(PB02a)_L6_C5
# 562: PFNm_b(PB02b)_L6_C5
# 563: PFNp_a(PB01a)_L6_C5
# 564: PFNp_b(PB01b)_L6_C5
# 565: PFNp_b(PB01b)_L6_C5
# 566: PFNd(PB04)_L6_C5
# 567: PEN_b(PB06b)_L6
# 568: PFNa(PB03)_L6_C5
# 569: PFNd(PB04)_L6_C5
# 570: PFNp_c(PB01c)_L6_C5
# 571: PFNp_a(PB01a)_L6_C5
# 572: PFNp_c(PB01c)_L6_C5
# 573: PFNp_a(PB01a)_L6_C5
# 574: PFNp_e(PB01a)_L6_C5
# 575: PFNm_b(PB02b)_L6_C5
# 576: PFNp_b(PB01b)_L7_C6
# 577: PFNm_a(PB02a)_L6_C5
# 578: PFNp_a(PB01a)_L6_C5
# 579: PFL1(PB12a)_R4_C5
# 580: PFR_a(PB11a)_R4_C6
# 581: PFGs(PB10)_L6_C6
# 582: PFL1(PB12a)_L6_C7
# 583: PFL3(PB12c)_L6_C8
# 584: PFR_a(PB11a)_L6_C7
# 585: PFL3(PB12c)_R3_C5
# 586: PFR_a(PB11a)_R3_C7
# 587: PFNp_c(PB01c)_L6_C5
# 588: PFNp_c(PB01c)_L6_C5
# 589: PFNp_b(PB01b)_L6_C5
# 590: PFNa(PB03)_L6_C5
# 591: PFNa(PB03)_L6_C5
# 592: PFNa(PB03)_L6_C5
# 593: PFNa(PB03)_L6_C5
# 594: PEN_b(PB06b)_L6
# 595: PFNa(PB03)_L6_C5
# 596: PFNp_b(PB01b)_L6_C5
# 597: PFNd(PB04)_L6_C5
# 598: PFNp_c(PB01c)_L6_C5
# 599: PFNv(PB05)_R4_C7
# 600: PFNv(PB05)_R4_C7
# 601: PFNd(PB04)_R4_C6
# 602: PFNa(PB03)_R4_C7
# 603: PFNd(PB04)_R4_C6
# 604: PFNa(PB03)_R4_C7
# 605: PEN_b(PB06b)_R4
# 606: PFNa(PB03)_R4_C7
# 607: PFNa(PB03)_R4_C7
# 608: PFNd(PB04)_R4_C6
# 609: PFNa(PB03)_R4_C7
# 610: PFNp_e(PB01a)_R4_C7
# 611: PFNp_b(PB01b)_R4_C7
# 612: PFNp_e(PB01a)_R4_C7
# 613: PFNp_b(PB01b)_R4_C7
# 614: PFNp_c(PB01c)_R4_C7
# 615: PFNm_a(PB02a)_R4_C7
# 616: PFNp_a(PB01a)_R4_C7
# 617: PFNm_a(PB02a)_R4_C7
# 618: PFNp_b(PB01b)_R4_C7
# 619: PFNp_a(PB01a)_R4_C7
# 620: PFNm_b(PB02b)_R4_C7
# 621: PFNp_b(PB01b)_R4_C7
# 622: PFNp_a(PB01a)_R4_C7
# 623: PFNp_c(PB01c)_R4_C7
# 624: PFNp_d(PB01a)_R4_C7
# 625: PFNp_b(PB01b)_R4_C7
# 626: PFNm_b(PB02b)_R4_C7
# 627: PFNp_d(PB01a)_R4_C7
# 628: PFNp_a(PB01a)_R4_C7
# 629: PFNp_c(PB01c)_R4_C7
# 630: PFNp_b(PB01b)_R4_C7
# 631: PFNp_b(PB01b)_R4_C7
# 632: PFNp_b(PB01b)_R4_C7
# 633: PFR_b(PB11b)_L5_C6
# 634: PEG(PB07)_L5
# 635: PFL3(PB12c)_L5_C7
# 636: PFL1(PB12a)_L5_C6
# 637: PFR_a(PB11a)_L5_C5
# 638: PFNp_b(PB01b)_R4_C7
# 639: PFL3(PB12c)_L5_C7
# 640: PFR_a(PB11a)_L5_C5
# 641: PFGs(PB10)_L5_C5
# 642: PFR_a(PB11a)_R4_C6
# 643: PFNp_b(PB01b)_R4_C7
# 644: PFNd(PB04)_R4_C6
# 645: PFNp_c(PB01c)_R4_C7
# 646: PFL3(PB12c)_R4_C4
# 647: PEN_b(PB06b)_R4
# 648: PFNa(PB03)_R4_C7
# 649: PFR_b(PB11b)_R4_C5
# 650: PFGs(PB10)_R4_C6
# 651: PFNp_a(PB01a)_L5_C4
# 652: PEN_a(PB06a)_L5
# 653: PFNv(PB05)_L5_C4
# 654: PFNp_b(PB01b)_L5_C4
# 655: PFNp_b(PB01b)_L5_C4
# 656: PFNp_e(PB01a)_L5_C4
# 657: PFNp_a(PB01a)_L5_C4
# 658: PFNp_c(PB01c)_L5_C4
# 659: PFNm_a(PB02a)_L5_C4
# 660: PFNp_c(PB01c)_L5_C4
# 661: PFNp_b(PB01b)_L5_C4
# 662: PFNp_a(PB01a)_L5_C4
# 663: PFNp_b(PB01b)_L5_C4
# 664: PFNa(PB03)_L5_C4
# 665: PFNd(PB04)_L5_C4
# 666: PFNd(PB04)_L5_C4
# 667: PFNa(PB03)_L5_C4
# 668: PEN_b(PB06b)_L5
# 669: PFR_a(PB11a)_L6_C6
# 670: PEG(PB07)_R3
# 671: PFGs(PB10)_R3_C7
# 672: PFR_a(PB11a)_R3_C7
# 673: PFL1(PB12a)_R3_C6
# 674: PFL3(PB12c)_R3_C5
# 675: PFL2(PB12b)_R3_C3
# 676: PFL2(PB12b)_R3_C3
# 677: PFR_b(PB11b)_L6_C7
# 678: PFR_b(PB11b)_R3_C6
# 679: PFR_b(PB11b)_R3_C7
# 680: PFNp_c(PB01c)_R3_C8
# 681: PFNd(PB04)_R3_C7
# 682: PFNp_e(PB01a)_R3_C8
# 683: PFNp_a(PB01a)_R3_C8
# 684: PFNp_b(PB01b)_R3_C8
# 685: PFNp_b(PB01b)_R3_C8
# 686: PFNp_b(PB01b)_R3_C8
# 687: PFNd(PB04)_R3_C7
# 688: PEN_b(PB06b)_R3
# 689: PFNa(PB03)_R3_C8
# 690: PFNa(PB03)_R3_C8
# 691: PFNp_a(PB01a)_R3_C8
# 692: PFNv(PB05)_R3_C8
# 693: PFNp_b(PB01b)_R3_C8
# 694: PFNp_b(PB01b)_R3_C8
# 695: PFNm_a(PB02a)_R3_C8
# 696: PFNp_a(PB01a)_R3_C8
# 697: PFNp_c(PB01c)_R3_C8
# 698: PFNp_d(PB01a)_R3_C8
# 699: PFNp_d(PB01a)_R3_C8
# 700: PFNm_b(PB02b)_R3_C8
# 701: PFNp_d(PB01a)_R_C8_irreg
# 702: ATL015_R
# 703: LAL148_R
# 704: ATL008_R
# 705: ATL044_R
# 706: LAL150_R
# 707: LAL147_R
# 708: PS286(PVM10)_R
# 709: ATL034(PDM32)_L
# 710: ATL022_R
# 711: ATL042_R
# 712: ExR3(ring)_R
# 713: LHPV3c1_R
# 714: LAL147_R
# 715: ATL018_R
# 716: PS107_R
# 717: PLP231_R
# 718: IB018_R
# 719: ATL035(PDM32)_L
# 720: FC1B(FQ6)_C3_R
# 721: FC1A(FQ6)_C3_R
# 722: PS286_L
# 723: vDeltaL_C7
# 724: FR2(FQ4)_C4_R_small
# 725: PLP142_R
# 726: hDeltaH_03_C2
# 727: hDeltaH_14_C8
# 728: ATL037(PDM33)_L
# 729: PS157_R
# 730: vDeltaM_C7
# 731: PFNp_b(PB01b)_R2_C9
# 732: PFNv(PB05)_R2_C9
# 733: PFNa(PB03)_R2_C9
# 734: PFNa(PB03)_R2_C9
# 735: PFNd(PB04)_R2_C8
# 736: PFNd(PB04)_R2_C8
# 737: PFNp_c(PB01c)_R2_C9
# 738: PFNp_b(PB01b)_R2_C9
# 739: PEN_b(PB06b)_R2
# 740: PFNa(PB03)_R2_C9
# 741: hDeltaC_06_C6
# 742: PFNm_b(PB02b)_R2_C9
# 743: PFNp_b(PB01b)_R2_C9
# 744: PFNp_b(PB01b)_R2_C9
# 745: PFNp_a(PB01a)_R2_C9
# 746: PFNp_b(PB01b)_R2_C9
# 747: PFNm_a(PB02a)_R2_C9
# 748: PFNp_c(PB01c)_R2_C9
# 749: PFNp_a(PB01a)_R2_C9
# 750: PFNp_e(PB01a)_R2_C9
# 751: PFNp_a(PB01a)_R2_C9
# 752: WED161_b_R
# 753: PFL2(PB12b)_R2_C4
# 754: PFR_a(PB11a)_R2_C8
# 755: PFNp_b(PB01b)_L7_C6
# 756: PFR_a(PB11a)_R2_C8
# 757: PFL1(PB12a)_R2_C7
# 758: PFL3(PB12c)_R2_C1_irreg
# 759: PFL3(PB12c)_R2_C6
# 760: PFNp_b(PB01b)_L6_C5
# 761: PFNp_a(PB01a)_L7_C6
# 762: PFNm_a(PB02a)_L7_C6
# 763: PFNp_c(PB01c)_L7_C6
# 764: PFNm_a(PB02a)_L7_C6
# 765: PFNp_d(PB01a)_L7_C6
# 766: PFNp_e(PB01a)_L7_C6
# 767: PFNp_c(PB01c)_L7_C6
# 768: PFNp_b(PB01b)_L7_C6
# 769: PFNp_b(PB01b)_L7_C6
# 770: PFNp_b(PB01b)_L7_C6
# 771: PFNa(PB03)_L7_C6
# 772: PEN_b(PB06b)_L7
# 773: PFNa(PB03)_L7_C6
# 774: PFNd(PB04)_L7_C6
# 775: PFNa(PB03)_L7_C6
# 776: PFNd(PB04)_L7_C6
# 777: PFNp_b(PB01b)_L7_C6
# 778: PFL3(PB12c)_L7_C9
# 779: PFL1(PB12a)_L7_C9
# 780: PFGs(PB10)_L7_C7
# 781: PFR_a(PB11a)_L7_C7
# 782: PFR_b(PB11b)_L7_C8
# 783: PFNv(PB05)_L7_C7
# 784: PFNp_d(PB01a)_R2_C9
# 785: PFGs(PB10)_R2_C8
# 786: PFNp_d(PB01a)_R2_C9
# 787: PFR_a(PB11a)_R2_C8
# 788: EL(EQ5)_L
# 789: PEN_a(PB06a)_R2
# 790: PEG(PB07)_R2
# 791: PFNp_a(PB01a)_L7_C6
# 792: PEN_a(PB06a)_L7
# 793: PEG(PB07)_L7
# 794: PFNp_a(PB01a)_L7_C6
# 795: PFNp_d(PB01a)_L7_C6

# %%
# Show original W matrix
plt.figure(figsize=(16, 6))

plt.subplot(1, 2, 1)
plt.imshow(W, cmap='Reds', aspect='equal', vmax=20)
plt.colorbar(label='Connection Strength')
plt.title('Original Matrix W')
plt.xlabel('Target Neuron')
plt.ylabel('Source Neuron')

plt.subplot(1, 2, 2)
plt.imshow(W_sorted, cmap='Reds', aspect='equal', vmax=20)
plt.colorbar(label='Connection Strength')
plt.title('Sorted Matrix W')
plt.xlabel('Target Neuron')
plt.ylabel('Source Neuron')

plt.tight_layout()
plt.show()

# %%
import numpy as np
from numpy.lib.stride_tricks import sliding_window_view
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

def find_best_submatrix(image: np.ndarray,
                        pattern: np.ndarray,
                        method: str = "ncc",
                        return_map: bool = True,
                        eps: float = 1e-12,
                        top_k: int = 1):
    """
    Find the top-k best matching submatrices in `image` that match `pattern`.

    - method="ncc": normalized cross-correlation in [-1, 1]; higher is more similar
    - method="ssd": negative sum of squared differences; higher (less negative) is more similar

    Returns:
        List of tuples: [(top, left, best_score, best_patch), ...] for top-k matches
        If return_map=True, also returns score_map as last element
    """
    image = np.asarray(image, dtype=np.float64)
    pattern = np.asarray(pattern, dtype=np.float64)

    if image.ndim != 2 or pattern.ndim != 2:
        raise ValueError("Both `image` and `pattern` must be 2D arrays.")

    H, W = image.shape
    h, w = pattern.shape
    if h > H or w > W:
        raise ValueError("`pattern` must be smaller than or equal to `image` in both dimensions.")

    # Sliding window view over the image to compare every h×w patch
    windows = sliding_window_view(image, (h, w))  # shape: (H-h+1, W-w+1, h, w)

    if method.lower() == "ncc":
        # Z-score the pattern
        pattern_mean = pattern.mean()
        pattern_std = pattern.std() + eps
        pattern_z = (pattern - pattern_mean) / pattern_std

        # Window-wise mean/std
        win_mean = windows.mean(axis=(2, 3))
        win_std = windows.std(axis=(2, 3)) + eps

        # Pearson correlation coefficient via z-scored dot product
        score_map = ((windows - win_mean[..., None, None]) * pattern_z).sum(axis=(2, 3)) / (win_std * (h * w))

    elif method.lower() == "ssd":
        # Negative SSD so that higher is better
        diffs = windows - pattern  # broadcast over (h, w)
        score_map = -np.square(diffs).sum(axis=(2, 3))

    else:
        raise ValueError("Unsupported method. Use 'ncc' or 'ssd'.")

    # Find top-k matches
    flat_scores = score_map.flatten()
    top_k_indices = np.argpartition(flat_scores, -top_k)[-top_k:]
    top_k_indices = top_k_indices[np.argsort(flat_scores[top_k_indices])[::-1]]  # Sort in descending order
    
    results = []
    for idx in top_k_indices:
        best_rc = np.unravel_index(idx, score_map.shape)
        top, left = int(best_rc[0]), int(best_rc[1])
        best_score = float(score_map[best_rc])
        best_patch = image[top:top + h, left:left + w]
        results.append((top, left, best_score, best_patch))

    if return_map:
        return results, score_map
    return results


# --- Example usage (uses matrix W if it exists in the notebook) ---
try:
    W = W_sorted
    H, Wn = W.shape  # noqa: F821
    # Choose a pattern size (use 16×16 if possible, else fall back to half size)
    ph = 16 if H >= 16 else max(1, H // 2)
    pw = 16 if Wn >= 16 else max(1, Wn // 2)
    pattern = W_pattern

    top_k = 10
    results, score_map = find_best_submatrix(W_sorted, W_pattern, method="ncc", return_map=True, top_k=top_k)

    k = min(top_k, len(results))
    print(f"Top {k} best matches:")
    for i, (top, left, score, sub) in enumerate(results[:k]):
        if 'sorted_neuron_names' in locals() and top < len(sorted_neuron_names) and left < len(sorted_neuron_names):
            row_name = sorted_neuron_names[top]
            col_name = sorted_neuron_names[left]
            name_str = f" [{row_name} -> {col_name}]"
        else:
            name_str = ""
        print(f"  {i+1}. Top-left at (row={top}, col={left}){name_str}, NCC={score:.4f}, pattern size=({ph}, {pw})")

    if k == 0:
        print("No matches found.")
    else:
        # Consistent color scaling for W (robust percentiles)
        W_vmin, W_vmax = np.percentile(W, 1), np.percentile(W, 99)

        colors = ['red', 'blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'olive', 'cyan']
        match_labels = ['1st best', '2nd best', '3rd best', '4th best', '5th best',
                        '6th best', '7th best', '8th best', '9th best', '10th best']

        # Figure 1: Full matrix with all top-k matches overlaid
        fig1, ax1 = plt.subplots(1, 1, figsize=(10, 8), constrained_layout=True)
        im1 = ax1.imshow(W, cmap="Reds", interpolation="nearest", vmin=W_vmin, vmax=W_vmax, aspect="equal")
        for i, (top, left, _, _) in enumerate(results[:k]):
            ax1.add_patch(Rectangle((left - 0.5, top - 0.5), pw, ph,
                                    edgecolor=colors[i], facecolor="none", linewidth=2,
                                    label=f"{match_labels[i]}") )
        ax1.set_title(f"Matrix W with top {k} matches")
        ax1.set_xlabel("Column")
        ax1.set_ylabel("Row")
        fig1.colorbar(im1, ax=ax1, shrink=0.85)
        ax1.legend(loc="upper right", fontsize=8, frameon=True)
        plt.show()

        # Figure 2: Compact zoom grid of top-k matches (2×5 by default)
        cols = min(5, k)
        rows = int(np.ceil(k / cols))
        fig2, axes2 = plt.subplots(rows, cols, figsize=(3.5 * cols, 3.5 * rows), constrained_layout=True)
        if rows == 1 and cols == 1:
            axes2 = np.array([[axes2]])
        elif rows == 1:
            axes2 = np.array([axes2])
        axes2 = axes2.reshape(rows, cols)

        im_for_cb = None
        for idx in range(rows * cols):
            r = idx // cols
            c = idx % cols
            ax = axes2[r, c]
            if idx < k:
                top, left, score, _ = results[idx]
                # Zoom bounds
                zoom_margin = 5
                zoom_top = max(0, top - zoom_margin)
                zoom_bottom = min(H, top + ph + zoom_margin)
                zoom_left = max(0, left - zoom_margin)
                zoom_right = min(Wn, left + pw + zoom_margin)

                zoom_region = W[zoom_top:zoom_bottom, zoom_left:zoom_right]
                im_for_cb = ax.imshow(zoom_region, cmap="Reds", interpolation="nearest",
                                      vmin=W_vmin, vmax=W_vmax, aspect="equal")
                # Rect in zoomed coords
                rect_top = top - zoom_top
                rect_left = left - zoom_left
                ax.add_patch(Rectangle((rect_left - 0.5, rect_top - 0.5), pw, ph,
                                       edgecolor=colors[idx], facecolor="none", linewidth=2))
                ax.set_title(f"{match_labels[idx]} (NCC={score:.3f})", fontsize=9)
                # Show neuron names on axes for the zoomed region (all labels)
                zoom_row_indices = list(range(zoom_top, zoom_bottom))
                zoom_col_indices = list(range(zoom_left, zoom_right))
                y_ticks = np.arange(len(zoom_row_indices))
                x_ticks = np.arange(len(zoom_col_indices))
                if 'sorted_neuron_names' in locals():
                    zoom_row_names = [sorted_neuron_names[j] if j < len(sorted_neuron_names) else f"Row {j}" for j in zoom_row_indices]
                    zoom_col_names = [sorted_neuron_names[j] if j < len(sorted_neuron_names) else f"Col {j}" for j in zoom_col_indices]
                else:
                    zoom_row_names = [f"Row {j}" for j in zoom_row_indices]
                    zoom_col_names = [f"Col {j}" for j in zoom_col_indices]
                ax.set_yticks(y_ticks)
                ax.set_yticklabels(zoom_row_names, fontsize=6)
                ax.set_xticks(x_ticks)
                ax.set_xticklabels(zoom_col_names, rotation=90, ha='right', fontsize=6)
            else:
                ax.axis("off")
        if im_for_cb is not None:
            fig2.colorbar(im_for_cb, ax=axes2.ravel().tolist(), shrink=0.85)
        plt.show()

        # Figure 3: Similarity map with top-k markers
        fig3, ax3 = plt.subplots(1, 1, figsize=(8, 6), constrained_layout=True)
        im3 = ax3.imshow(score_map, cmap="magma", interpolation="nearest", aspect="equal")
        for i, (top, left, score, _) in enumerate(results[:k]):
            ax3.plot(left, top, marker='o', markersize=6, color=colors[i],
                     markeredgecolor='white', markeredgewidth=1.5,
                     label=f"{match_labels[i]} ({score:.3f})")
        ax3.set_title(f"Similarity map (NCC) with top {k} matches")
        ax3.set_xlabel("Left column index")
        ax3.set_ylabel("Top row index")
        ax3.legend(bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=8)
        fig3.colorbar(im3, ax=ax3, shrink=0.85)
        plt.show()

except NameError:
    # If W is not defined yet in the notebook, just define a tiny demo
    demo = np.random.rand(32, 32)
    tpl = demo[8:16, 10:18] + 0.25  # make a slightly brighter patch
    results, smap = find_best_submatrix(demo, tpl, method="ssd", return_map=True, top_k=10)
    print("(Demo) Top 10 matches:")
    for i, (t, l, s, sub) in enumerate(results):
        print(f"  {i+1}. Best match at (row={t}, col={l}), SSD={s:.4f}")
# Out:
# Top 10 best matches:
#   1. Top-left at (row=249, col=257) [PFNd(PB04)_L3_C2 -> PFNp_c(PB01c)_L3_C2], NCC=0.3314, pattern size=(16, 16)
#   2. Top-left at (row=436, col=47) [PEN_b(PB06b)_R8 -> SIFa(PDM34)], NCC=0.3314, pattern size=(16, 16)
#   3. Top-left at (row=343, col=416) [PFNp_b(PB01b)_L2_C1 -> PEG(PB07)_L9], NCC=0.3200, pattern size=(16, 16)
#   4. Top-left at (row=339, col=412) [PFNp_e(PB01a)_L2_C1 -> PEN_b(PB06b)_L9], NCC=0.3120, pattern size=(16, 16)
#   5. Top-left at (row=541, col=540) [PFNp_e(PB01a)_L6_C5 -> PFNp_b(PB01b)_L6_C5], NCC=0.3110, pattern size=(16, 16)
#   6. Top-left at (row=655, col=69) [PFNp_b(PB01b)_L5_C4 -> EPG(PB08)_R5], NCC=0.3052, pattern size=(16, 16)
#   7. Top-left at (row=654, col=149) [PFNp_b(PB01b)_L5_C4 -> P6-8P9(PB14)_R], NCC=0.3023, pattern size=(16, 16)
#   8. Top-left at (row=655, col=150) [PFNp_b(PB01b)_L5_C4 -> P6-8P9(PB14)_R], NCC=0.3000, pattern size=(16, 16)
#   9. Top-left at (row=96, col=411) [SpsP(PB16)_L -> PEN_b(PB06b)_L9], NCC=0.2995, pattern size=(16, 16)
#   10. Top-left at (row=663, col=158) [PFNp_b(PB01b)_L5_C4 -> PFR_a(PB11a)_R5_C5], NCC=0.2995, pattern size=(16, 16)
